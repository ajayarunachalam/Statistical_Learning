# %%
college = read.csv("College.csv")
head(college)
# Out:
#   X                            Private Apps Accept Enroll Top10perc Top25perc
# 1 Abilene Christian University Yes     1660 1232   721    23        52
# 2 Adelphi University           Yes     2186 1924   512    16        29
# 3 Adrian College               Yes     1428 1097   336    22        50
# 4 Agnes Scott College          Yes      417  349   137    60        89
# 5 Alaska Pacific University    Yes      193  146    55    16        44
# 6 Albertson College            Yes      587  479   158    38        62
#   F.Undergrad P.Undergrad Outstate Room.Board Books Personal PhD Terminal
# 1 2885         537         7440    3300       450   2200     70  78
# 2 2683        1227        12280    6450       750   1500     29  30
# 3 1036          99        11250    3750       400   1165     53  66
# 4  510          63        12960    5450       450    875     92  97
# 5  249         869         7560    4120       800   1500     76  72
# ...

# %%
rownames(college)=college[,1]

# %%
head(college)
# Out:
#                              X                            Private Apps Accept
# Abilene Christian University Abilene Christian University Yes     1660 1232
# Adelphi University           Adelphi University           Yes     2186 1924
# Adrian College               Adrian College               Yes     1428 1097
# Agnes Scott College          Agnes Scott College          Yes      417  349
# Alaska Pacific University    Alaska Pacific University    Yes      193  146
# Albertson College            Albertson College            Yes      587  479
#                              Enroll Top10perc Top25perc F.Undergrad P.Undergrad
# Abilene Christian University 721    23        52        2885         537
# Adelphi University           512    16        29        2683        1227
# Adrian College               336    22        50        1036          99
# Agnes Scott College          137    60        89         510          63
# ...

# %%
college = college[,-1]

# %%
head(college)
# Out:
#                              Private Apps Accept Enroll Top10perc Top25perc
# Abilene Christian University Yes     1660 1232   721    23        52
# Adelphi University           Yes     2186 1924   512    16        29
# Adrian College               Yes     1428 1097   336    22        50
# Agnes Scott College          Yes      417  349   137    60        89
# Alaska Pacific University    Yes      193  146    55    16        44
# Albertson College            Yes      587  479   158    38        62
#                              F.Undergrad P.Undergrad Outstate Room.Board Books
# Abilene Christian University 2885         537         7440    3300       450
# Adelphi University           2683        1227        12280    6450       750
# Adrian College               1036          99        11250    3750       400
# Agnes Scott College           510          63        12960    5450       450
# Alaska Pacific University     249         869         7560    4120       800
# ...

# %%
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %%
pairs(college[,1:10], col=4)
# Out:
# plot without title

# %%
private <- as.factor(college$Private)
plot(private,college$Outstate, col="green", varwidth=T, xlab="Private", ylab="Outstate")
# Out:
# plot without title

# %%
Elite <- rep("No", nrow(college))
Elite[college$Top10perc>50] <- "Yes"
Elite <- as.factor(Elite)
college <- data.frame(college, Elite)

# %%
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %%
plot(Elite, college$Outstate,col="red", varwidth=T, xlab="Elite", ylab="Outstate")
# Out:
# plot without title

# %%
par(mfrow=c(2,2))
hist(college$Accept,col=4, breaks=15)
hist(college$Enroll,col=5, breaks=15)
hist(college$Room.Board,col=6, breaks=15)
hist(college$Books,col=7, breaks=15)
# Out:
# Plot with title “Histogram of college$Books”

# %%
pairs(~F.Undergrad+P.Undergrad+Personal+PhD+Terminal, college, col=6)
# Out:
# plot without title

# %%
plot(college$S.F.Ratio, college$perc.alumni, col=4)
# Out:
# plot without title

# %%
# Auto Dataset

# %%
Auto <- read.table("Auto.data", header=T, na.strings = "?")

# %%
dim(Auto)
# Out:
# [1] 397   9

# %%
Auto <- na.omit(Auto)
dim(Auto)
# Out:
# [1] 392   9

# %%
head(Auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name
# 1 chevrolet chevelle malibu
# 2 buick skylark 320
# 3 plymouth satellite
# 4 amc rebel sst
# 5 ford torino
# 6 ford galaxie 500

# %%
range(Auto$mpg)
range(Auto$cylinders)
range(Auto$displacement)
range(Auto$horsepower)
range(Auto$weight)
range(Auto$acceleration)
range(Auto$year)
range(Auto$origin)
# Out:
# [1]  9.0 46.6
# [1] 3 8
# [1]  68 455
# [1]  46 230
# [1] 1613 5140
# [1]  8.0 24.8
# [1] 70 82
# [1] 1 3

# %%
mean(Auto$mpg)
mean(Auto$cylinders)
mean(Auto$displacement)
mean(Auto$horsepower)
mean(Auto$weight)
mean(Auto$acceleration)
mean(Auto$year)
mean(Auto$origin)
# Out:
# [1] 23.44592
# [1] 5.471939
# [1] 194.412
# [1] 104.4694
# [1] 2977.584
# [1] 15.54133
# [1] 75.97959
# [1] 1.576531

# %%
sd(Auto$mpg)
sd(Auto$cylinders)
sd(Auto$displacement)
sd(Auto$horsepower)
sd(Auto$weight)
sd(Auto$acceleration)
sd(Auto$year)
sd(Auto$origin)
# Out:
# [1] 7.805007
# [1] 1.705783
# [1] 104.644
# [1] 38.49116
# [1] 849.4026
# [1] 2.758864
# [1] 3.683737
# [1] 0.8055182

# %%
Auto_new <- Auto[-c(10:85),]
dim(Auto_new)
# Out:
# [1] 316   9

# %%
summary(Auto_new)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   :11.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1649
#  1st Qu.:18.00   1st Qu.:4.000   1st Qu.:100.2   1st Qu.: 75.0   1st Qu.:2214
#  Median :23.95   Median :4.000   Median :145.5   Median : 90.0   Median :2792
#  Mean   :24.40   Mean   :5.373   Mean   :187.2   Mean   :100.7   Mean   :2936
#  3rd Qu.:30.55   3rd Qu.:6.000   3rd Qu.:250.0   3rd Qu.:115.0   3rd Qu.:3508
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :4997
#
#   acceleration        year           origin
#  Min.   : 8.50   Min.   :70.00   Min.   :1.000
#  1st Qu.:14.00   1st Qu.:75.00   1st Qu.:1.000
#  Median :15.50   Median :77.00   Median :1.000
#  Mean   :15.73   Mean   :77.15   Mean   :1.601
#  3rd Qu.:17.30   3rd Qu.:80.00   3rd Qu.:2.000
#  Max.   :24.80   Max.   :82.00   Max.   :3.000
#
#                         name
#  ford pinto               :  5
#  toyota corolla           :  5
# ...

# %%
pairs(Auto)
# Out:
# plot without title

# %%
par(mfrow = c(3,3))
plot(Auto$mpg, Auto$cylinders)
plot(Auto$mpg, Auto$displacement, col=2)
plot(Auto$mpg, Auto$horsepower, col=3)
plot(Auto$mpg, Auto$weight, col=4)
plot(Auto$mpg, Auto$acceleration, col=5)
plot(Auto$mpg, Auto$year, col=6)
plot(Auto$mpg, Auto$origin, col=7)
# Out:
# plot without title

# %%
library(MASS)

# %%
?Boston

# %% [markdown]
# This data frame contains the following columns:
#
# crim
# per capita crime rate by town.
#
# zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
#
# indus
# proportion of non-retail business acres per town.
#
# chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# nox
# nitrogen oxides concentration (parts per 10 million).
#
# rm
# average number of rooms per dwelling.
#
# age
# proportion of owner-occupied units built prior to 1940.
#
# dis
# weighted mean of distances to five Boston employment centres.
#
# rad
# index of accessibility to radial highways.
#
# tax
# full-value property-tax rate per \$10,000.
#
# ptratio
# pupil-teacher ratio by town.
#
# black
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# lstat
# lower status of the population (percent).
#
# medv
# median value of owner-occupied homes in \$1000s.

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
pairs(Boston)
# Out:
# plot without title

# %%
names(Boston)
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
par(mfrow = c(3,3))
plot(Boston$crim, Boston$zn)
plot(Boston$crim, Boston$indus, col=2)
plot(Boston$crim, Boston$chas, col=3)
plot(Boston$crim, Boston$nox, col=4)
plot(Boston$crim, Boston$rm, col=5)
plot(Boston$crim, Boston$age, col=6)
plot(Boston$crim, Boston$dis, col=7)
plot(Boston$crim, Boston$rad, col=8)
plot(Boston$crim, Boston$tax, col=9)
plot(Boston$crim, Boston$ptratio, col=10)
plot(Boston$crim, Boston$black, col=11)
plot(Boston$crim, Boston$lstat, col=12)
plot(Boston$crim, Boston$medv, col=13)
# Out:
# plot without title
# plot without title

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %%
Boston[which(Boston$crim>50),]
# Out:
#     crim    zn indus chas nox   rm    age   dis    rad tax ptratio black  lstat
# 381 88.9762 0  18.1  0    0.671 6.968  91.9 1.4165 24  666 20.2    396.90 17.21
# 406 67.9208 0  18.1  0    0.693 5.683 100.0 1.4254 24  666 20.2    384.97 22.98
# 411 51.1358 0  18.1  0    0.597 5.757 100.0 1.4130 24  666 20.2      2.60 10.11
# 419 73.5341 0  18.1  0    0.679 5.957 100.0 1.8026 24  666 20.2     16.45 20.62
#     medv
# 381 10.4
# 406  5.0
# 411 15.0
# 419  8.8

# %%
Boston[which(Boston$tax>mean(Boston$tax)),]
# Out:
#     crim     zn indus chas nox   rm    age   dis     rad tax ptratio black
# 55  0.01360  75  4.00 0    0.410 5.888  47.6  7.3197 3   469 21.1    396.90
# 112 0.10084   0 10.01 0    0.547 6.715  81.6  2.6775 6   432 17.8    395.59
# 113 0.12329   0 10.01 0    0.547 5.913  92.9  2.3534 6   432 17.8    394.95
# 114 0.22212   0 10.01 0    0.547 6.092  95.4  2.5480 6   432 17.8    396.90
# 115 0.14231   0 10.01 0    0.547 6.254  84.2  2.2565 6   432 17.8    388.74
# 116 0.17134   0 10.01 0    0.547 5.928  88.2  2.4631 6   432 17.8    344.91
# 117 0.13158   0 10.01 0    0.547 6.176  72.5  2.7301 6   432 17.8    393.30
# 118 0.15098   0 10.01 0    0.547 6.021  82.6  2.7474 6   432 17.8    394.51
# 119 0.13058   0 10.01 0    0.547 5.872  73.1  2.4775 6   432 17.8    338.63
# 120 0.14476   0 10.01 0    0.547 5.731  65.2  2.7592 6   432 17.8    391.50
# 128 0.25915   0 21.89 0    0.624 5.693  96.0  1.7883 4   437 21.2    392.11
# ...
